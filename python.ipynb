# %%
import os
print(os.getcwd())
# Out:
# c:\Users\drhum\OneDrive\Desktop\Fall 2025\CMSE 830 Foundation for Data Science\Project\cmse830_fds

# %%
import yaml

with open("config.yaml", "r", encoding="utf-8") as f:
    conf = yaml.safe_load(f)

print(conf["heart"]["numeric"])
# Out:
# ['age', 'tresbps', 'chol', 'thalach', 'oldpeak', 'ca']
